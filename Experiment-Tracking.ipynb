# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://localhost:8090")

# %%
mlflow.set_experiment("MyNewExperiment")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/446063747226187914', creation_time=1714731402251, experiment_id='446063747226187914', last_update_time=1714731402251, lifecycle_stage='active', name='MyNewExperiment', tags={'mlflow.note.content': 'Testing out the mLFlow Features. ',
#  'mlflow.sharedViewState.d537fdc0c959fa49a2e0b67727b54010fcd4ffd194d195a2598ac3fdf5c6e596': '{"searchFilter":"","orderByKey":"attributes.start_time","orderByAsc":false,"startTime":"ALL","lifecycleFilter":"Active","datasetsFilter":[],"modelVersionFilter":"All '
#                                                                                             'Runs","selectedColumns":["attributes.`Source`","attributes.`Models`","attributes.`Dataset`"],"runsExpanded":{},"runsPinned":[],"runsHidden":[],"runsHiddenMode":"FIRST_10_RUNS","viewMaximized":false,"runListHidden":false,"isAccordionReordered":false,"groupBy":"","groupsExpanded":{}}'}>

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

# %%
mlflow.autolog()
# Out:
# 2024/05/03 15:55:12 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.

# %%
db = load_diabetes()

# %%
X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

# %%
rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)

# %%
rf.fit(X_train, y_train)
# Out:
# 2024/05/03 15:55:20 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1618aeea56874cbfb7e00b80ddc3ef37', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/05/03 15:55:22 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/fourofour/Professional/Jio-2024/JIO-MLOPS-24/Auto-Logging/monitoring-env/lib/python3.11/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils."
# RandomForestRegressor(max_depth=6, max_features=3)

# %%
import mlflow
logged_model = 'runs:/1618aeea56874cbfb7e00b80ddc3ef37/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# Predict on a Pandas DataFrame.
# import pandas as pd
# loaded_model.predict(pd.DataFrame(data))

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: model
#   flavor: mlflow.sklearn
#   run_id: 1618aeea56874cbfb7e00b80ddc3ef37

# %%
import pandas as pd

# %%
# !pip install numpy

# %%
# Create a numpy array with random data
import numpy as np
data = np.random.rand(1, 10)  # Example: 20 rows, 10 columns

# Convert the numpy array to a pandas DataFrame
df = pd.DataFrame(data)
print( data )
# Out:
# [[0.96739171 0.29263285 0.72318007 0.21567142 0.9465861  0.03352874
#   0.89839728 0.0993049  0.13885935 0.7136337 ]]

# %%
loaded_model.predict(pd.DataFrame(data))
# Out:
# array([237.87080626])
